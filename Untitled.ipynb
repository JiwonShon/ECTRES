# %%
# Import libries
import numpy as np
import pandas as pd
import os
import re
import glob
import json
import csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pyranges as pr
import pysam
# from scipy.stats import mannwhitneyu, stats
# from statannotations.Annotator import Annotator

current_directory = os.getcwd()
print("Current Directory:", current_directory)
pd.set_option("display.max_columns", None)
# Out:
# Current Directory: /mnt/NAS3/home/jiwon/ECTRES/python

# %% [markdown]
# ## Manifest & sample barcoding

# %%
manifest=pd.read_csv('../manifest/ECTRES_clones_nf_dna_fastqs.csv')
manifest.head()

# manifest['aliquot_barcode'].nunique()
# Out:
#                         aliquot_barcode source_barcode
# 0  ECTRES-ECGI1-0001-TPX-A01-WGS-6DM349          ECGI1  \
# 1  ECTRES-ECGI1-0001-TPX-A01-WGS-6DM349          ECGI1
# 2  ECTRES-ECGI1-0001-TPX-A10-WGS-3SW949          ECGI1
# 3  ECTRES-ECGI1-0001-TPX-A11-WGS-9HJ669          ECGI1
# 4  ECTRES-ECGI1-0001-TPX-A12-WGS-4SL389          ECGI1
#
#               sample_barcode    patient_barcode sample_type tumor_or_normal
# 0  ECTRES-ECGI1-0001-TPX-A01  ECTRES-ECGI1-0001          TP           tumor  \
# 1  ECTRES-ECGI1-0001-TPX-A01  ECTRES-ECGI1-0001          TP           tumor
# 2  ECTRES-ECGI1-0001-TPX-A10  ECTRES-ECGI1-0001          TP           tumor
# 3  ECTRES-ECGI1-0001-TPX-A11  ECTRES-ECGI1-0001          TP           tumor
# 4  ECTRES-ECGI1-0001-TPX-A12  ECTRES-ECGI1-0001          TP           tumor
#
#   sequence_type sample_legacy_id gender     RGID      RGPL         RGPU
# 0           WGS             EG_1     XY  2333V.6  ILLUMINA  2333VCLT4.6  \
# 1           WGS             EG_1     XY  232NW.1  ILLUMINA  232NW2LT3.1
# 2           WGS            EG_10     XY  232N3.8  ILLUMINA  232N3WLT3.8
# 3           WGS            EG_11     XY  232N3.8  ILLUMINA  232N3WLT3.8
# 4           WGS            EG_12     XY  232N3.8  ILLUMINA  232N3WLT3.8
#
#             RGLB  RGDT RGCN
# 0  ZKDN250032992   NaN  CBM  \
# 1  ZKDN250032992   NaN  CBM
# 2  ZKDN250033001   NaN  CBM
# 3  ZKDN250033002   NaN  CBM
# 4  ZKDN250033003   NaN  CBM
#
#                                                  FQ1
# 0  /mnt/NAS3/home/mary/rawData/ECTRES/X209SC25116...  \
# 1  /mnt/NAS3/home/mary/rawData/ECTRES/X209SC25116...
# 2  /mnt/NAS3/home/mary/rawData/ECTRES/X209SC25116...
# 3  /mnt/NAS3/home/mary/rawData/ECTRES/X209SC25116...
# 4  /mnt/NAS3/home/mary/rawData/ECTRES/X209SC25116...
#
#                                                  FQ2 action
# 0  /mnt/NAS3/home/mary/rawData/ECTRES/X209SC25116...    run
# 1  /mnt/NAS3/home/mary/rawData/ECTRES/X209SC25116...    run
# 2  /mnt/NAS3/home/mary/rawData/ECTRES/X209SC25116...    run
# 3  /mnt/NAS3/home/mary/rawData/ECTRES/X209SC25116...    run
# 4  /mnt/NAS3/home/mary/rawData/ECTRES/X209SC25116...    run

# %%
manifest["sample_id"] = manifest["sample_legacy_id"].fillna("parental")
sample_mapping = manifest[['aliquot_barcode','source_barcode','sample_barcode','patient_barcode','sample_id']].drop_duplicates()

print(manifest.shape, sample_mapping.shape)
# Out:
# (63, 19) (53, 5)

# %%
# sample_mapping.head()

# %% [markdown]
# ## Amplicon Architect

# %%
base_dir = '../summary/aaSuite_germline_ms/-1X'

# %%
# !ls ../summary/aaSuite_germline_ms/-1X/
# Out:
# log_20260224.txt
# scratch-aaSuite_germline_ms-v1.3.8-GRCh37-minCN4.5-cnsizeMin50000--1X_20260224_annotated_cycles_files.csv
# scratch-aaSuite_germline_ms-v1.3.8-GRCh37-minCN4.5-cnsizeMin50000--1X_20260224_combined_aa_amplicons.csv
# scratch-aaSuite_germline_ms-v1.3.8-GRCh37-minCN4.5-cnsizeMin50000--1X_20260224_combined_amplicon_classification_profiles.csv
# scratch-aaSuite_germline_ms-v1.3.8-GRCh37-minCN4.5-cnsizeMin50000--1X_20260224_combined_ecDNA_counts.csv
# scratch-aaSuite_germline_ms-v1.3.8-GRCh37-minCN4.5-cnsizeMin50000--1X_20260224_combined_feature_basic_properties.csv
# scratch-aaSuite_germline_ms-v1.3.8-GRCh37-minCN4.5-cnsizeMin50000--1X_20260224_combined_feature_entropy.csv
# scratch-aaSuite_germline_ms-v1.3.8-GRCh37-minCN4.5-cnsizeMin50000--1X_20260224_combined_gene_list.csv

# %%
aa_classification=pd.read_csv(f'{base_dir}/scratch-aaSuite_germline_ms-v1.3.8-GRCh37-minCN4.5-cnsizeMin50000--1X_20260224_combined_amplicon_classification_profiles.csv')

print(aa_classification.shape)
aa_classification.head()
# Out:
# (1904, 8)
#                                   amplicon_barcode
# 0  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461-amplicon10  \
# 1  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461-amplicon11
# 2  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461-amplicon12
# 3  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461-amplicon13
# 4  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461-amplicon14
#
#                              aa_barcode                           sample_name
# 0  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461  \
# 1  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461
# 2  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461
# 3  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461
# 4  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461
#
#   amplicon_number amplicon_decomposition_class         ecDNA+           BFB+
# 0      amplicon10               No amp/Invalid  None detected  None detected  \
# 1      amplicon11               No amp/Invalid  None detected  None detected
# 2      amplicon12         Linear amplification  None detected  None detected
# 3      amplicon13         Linear amplification  None detected  None detected
# 4      amplicon14               No amp/Invalid  None detected  None detected
#
#    ecDNA_amplicons
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
aa_classification.describe(include='object')
# Out:
#                                        amplicon_barcode
# count                                              1904  \
# unique                                             1904
# top     ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461-amplicon10
# freq                                                  1
#
#                                   aa_barcode
# count                                   1904  \
# unique                                    52
# top     ECTRES-ECGI1-0001-TPX-A29-WGS-1IJ826
# freq                                      46
#
#                                  sample_name amplicon_number
# count                                   1904            1904  \
# unique                                    52              46
# top     ECTRES-ECGI1-0001-TPX-A29-WGS-1IJ826      amplicon10
# freq                                      46              52
#
#        amplicon_decomposition_class         ecDNA+           BFB+
# count                          1904           1904           1904
# unique                            4              2              2
# top                  No amp/Invalid  None detected  None detected
# freq                           1089           1873           1838

# %%
aa_amplicons=pd.read_csv(f'{base_dir}/scratch-aaSuite_germline_ms-v1.3.8-GRCh37-minCN4.5-cnsizeMin50000--1X_20260224_combined_aa_amplicons.csv')

print(aa_amplicons.shape)
# aa_amplicons.head()
# Out:
# (1904, 18)

# %%
aaSuite_gemline_ms_merge = pd.merge(aa_classification, aa_amplicons, how='inner', on=['amplicon_barcode', 'aa_barcode'])
aaSuite_gemline_ms_merge.shape
# Out:
# (1904, 24)

# %%
# aaSuite_gemline_ms_merge.head()

# %%
sample_mapping.columns
# Out:
# Index(['aliquot_barcode', 'source_barcode', 'sample_barcode',
#        'patient_barcode', 'sample_id'],
#       dtype='object')

# %%
sample_mapping['aa_barcode'] = sample_mapping['aliquot_barcode']

aaSuite_gemline_ms = pd.merge(aaSuite_gemline_ms_merge, sample_mapping[['aa_barcode','source_barcode','sample_id']], how='left', on=['aa_barcode'])

aaSuite_gemline_ms = aaSuite_gemline_ms.drop(columns=["sample_name"])

aaSuite_gemline_ms
# Out:
#                                      amplicon_barcode
# 0     ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461-amplicon10  \
# 1     ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461-amplicon11
# 2     ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461-amplicon12
# 3     ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461-amplicon13
# 4     ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461-amplicon14
# ...                                               ...
# 1899   ECTRES-H2170-0001-TPX-A01-WGS-3YV111-amplicon5
# 1900   ECTRES-H2170-0001-TPX-A01-WGS-3YV111-amplicon6
# 1901   ECTRES-H2170-0001-TPX-A01-WGS-3YV111-amplicon7
# 1902   ECTRES-H2170-0001-TPX-A01-WGS-3YV111-amplicon8
# 1903   ECTRES-H2170-0001-TPX-A01-WGS-3YV111-amplicon9
#
#                                 aa_barcode
# 0     ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461  \
# 1     ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461
# 2     ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461
# 3     ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461
# 4     ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461
# ...                                    ...
# 1899  ECTRES-H2170-0001-TPX-A01-WGS-3YV111
# 1900  ECTRES-H2170-0001-TPX-A01-WGS-3YV111
# 1901  ECTRES-H2170-0001-TPX-A01-WGS-3YV111
# 1902  ECTRES-H2170-0001-TPX-A01-WGS-3YV111
# 1903  ECTRES-H2170-0001-TPX-A01-WGS-3YV111
#
#                                sample_name amplicon_number
# 0     ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461      amplicon10  \
# 1     ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461      amplicon11
# 2     ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461      amplicon12
# 3     ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461      amplicon13
# 4     ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461      amplicon14
# ...                                    ...             ...
# 1899  ECTRES-H2170-0001-TPX-A01-WGS-3YV111       amplicon5
# 1900  ECTRES-H2170-0001-TPX-A01-WGS-3YV111       amplicon6
# 1901  ECTRES-H2170-0001-TPX-A01-WGS-3YV111       amplicon7
# 1902  ECTRES-H2170-0001-TPX-A01-WGS-3YV111       amplicon8
# 1903  ECTRES-H2170-0001-TPX-A01-WGS-3YV111       amplicon9
#
#      amplicon_decomposition_class         ecDNA+           BFB+
# 0                  No amp/Invalid  None detected  None detected  \
# 1                  No amp/Invalid  None detected  None detected
# 2            Linear amplification  None detected  None detected
# 3            Linear amplification  None detected  None detected
# 4                  No amp/Invalid  None detected  None detected
# ...                           ...            ...            ...
# 1899                       Cyclic       Positive  None detected
# 1900               No amp/Invalid  None detected  None detected
# 1901               No amp/Invalid  None detected  None detected
# 1902               No amp/Invalid  None detected  None detected
# 1903               No amp/Invalid  None detected  None detected
#
#       ecDNA_amplicons  AmpliconID amplicon_index
# 0                   0          10     amplicon10  \
# 1                   0          11     amplicon11
# 2                   0          12     amplicon12
# 3                   0          13     amplicon13
# 4                   0          14     amplicon14
# ...               ...         ...            ...
# 1899                2           5      amplicon5
# 1900                0           6      amplicon6
# 1901                0           7      amplicon7
# 1902                0           8      amplicon8
# 1903                0           9      amplicon9
#
#                                    aa_summary_file_path  N_Intervals
# 0     /mnt/NAS3/home/mary/HL-NF/scratch/ECTRES/resul...            1  \
# 1     /mnt/NAS3/home/mary/HL-NF/scratch/ECTRES/resul...            1
# 2     /mnt/NAS3/home/mary/HL-NF/scratch/ECTRES/resul...            2
# 3     /mnt/NAS3/home/mary/HL-NF/scratch/ECTRES/resul...            1
# 4     /mnt/NAS3/home/mary/HL-NF/scratch/ECTRES/resul...            1
# ...                                                 ...          ...
# 1899  /mnt/NAS3/home/mary/HL-NF/scratch/ECTRES/resul...            8
# 1900  /mnt/NAS3/home/mary/HL-NF/scratch/ECTRES/resul...            1
# 1901  /mnt/NAS3/home/mary/HL-NF/scratch/ECTRES/resul...            1
# 1902  /mnt/NAS3/home/mary/HL-NF/scratch/ECTRES/resul...            2
# 1903  /mnt/NAS3/home/mary/HL-NF/scratch/ECTRES/resul...            1
#
#                                               Intervals
# 0                                      5:580025-2945112  \
# 1                                   5:56760725-56995730
# 2               6:55197775-58257661,6:58341596-58700002
# 3                                   6:63300000-64633728
# 4                                     7:3427367-3487367
# ...                                                 ...
# 1899  3:111174085-111384740,8:102090335-102300990,8:...
# 1900                                    5:685025-835032
# 1901                                6:55252773-57297692
# 1902            6:58416576-58700002,6:62078599-62099255
# 1903                                6:63300000-64518727
#
#                                      OncogenesAmplified  TotalIntervalSize
# 0                                                 TERT,            2365088  \
# 1                                                     ,             235006
# 2                                                RAB23,            3418294
# 3                                               PTP4A1,            1333729
# 4                                                     ,              60001
# ...                                                 ...                ...
# 1899  ERBB2,RARA,PVT1,CDK12,THRA,PRMT5,FOXA1,C17orf3...           17521910
# 1900                                                  ,             150008
# 1901                                             RAB23,            2044920
# 1902                                                  ,             304084
# 1903                                            PTP4A1,            1218728
#
#       AmplifiedIntervalSize  AverageAmplifiedCopyCount  N_Chromosomes
# 0                   2365085                   4.544923              1  \
# 1                    235005                   3.713199              1
# 2                   3357386                   5.672345              1
# 3                   1216199                   6.019590              1
# 4                     60000                   3.777979              1
# ...                     ...                        ...            ...
# 1899               16228909                  22.117770              4
# 1900                 150007                   3.307941              1
# 1901                      0                   2.000000              1
# 1902                      0                   2.000000              1
# 1903                      0                   2.000000              1
#
#       N_SeqenceEdges  N_BreakpointEdges  N_CoverageShifts
# 0                  3                  0                 2  \
# 1                  1                  0                 0
# 2                  9                  1                 5
# 3                  2                  0                 1
# 4                  1                  0                 0
# ...              ...                ...               ...
# 1899              93                 31                26
# 1900               1                  0                 0
# 1901               2                  0                 0
# 1902               9                  2                 0
# 1903               2                  1                 0
#
#       N_MeanshiftSegmentsCopyCount>5  N_Foldbacks
# 0                                  1            0  \
# 1                                  0            0
# 2                                  1            1
# 3                                  0            0
# 4                                  0            0
# ...                              ...          ...
# 1899                               6            7
# 1900                               0            0
# 1901                               0            0
# 1902                               0            0
# 1903                               0            0
#
#       N_CoverageShiftsWithBreakpointEdges source_barcode sample_id
# 0                                       2          ECGI1      EG_8
# 1                                       0          ECGI1      EG_8
# 2                                       5          ECGI1      EG_8
# 3                                       1          ECGI1      EG_8
# 4                                       0          ECGI1      EG_8
# ...                                   ...            ...       ...
# 1899                                   14          H2170  parental
# 1900                                    0          H2170  parental
# 1901                                    0          H2170  parental
# 1902                                    0          H2170  parental
# 1903                                    0          H2170  parental
#
# [1904 rows x 26 columns]

# %%
# aaSuite_gemline_ms['source_barcode'].unique()
# Out:
# array(['ECGI1', 'H2170'], dtype=object)

# %%
aaSuite_gemline_ms_ECGI=aaSuite_gemline_ms[aaSuite_gemline_ms['source_barcode']=='ECGI1']
aaSuite_gemline_ms_ECGI.shape
# Out:
# (1494, 26)

# %%
# aaSuite_gemline_ms_ECGI.to_csv('../summary/aaSuite_germline_ms/-1X/aaSuite_gemline_ms_ECGI.csv',index=False)

# %%
aaSuite_gemline_ms_ECGI.head()
# Out:
#                                   amplicon_barcode
# 0  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461-amplicon10  \
# 1  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461-amplicon11
# 2  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461-amplicon12
# 3  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461-amplicon13
# 4  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461-amplicon14
#
#                              aa_barcode                           sample_name
# 0  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461  \
# 1  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461
# 2  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461
# 3  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461
# 4  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461  ECTRES-ECGI1-0001-TPX-A08-WGS-2YW461
#
#   amplicon_number amplicon_decomposition_class         ecDNA+           BFB+
# 0      amplicon10               No amp/Invalid  None detected  None detected  \
# 1      amplicon11               No amp/Invalid  None detected  None detected
# 2      amplicon12         Linear amplification  None detected  None detected
# 3      amplicon13         Linear amplification  None detected  None detected
# 4      amplicon14               No amp/Invalid  None detected  None detected
#
#    ecDNA_amplicons  AmpliconID amplicon_index
# 0                0          10     amplicon10  \
# 1                0          11     amplicon11
# 2                0          12     amplicon12
# 3                0          13     amplicon13
# 4                0          14     amplicon14
#
#                                 aa_summary_file_path  N_Intervals
# 0  /mnt/NAS3/home/mary/HL-NF/scratch/ECTRES/resul...            1  \
# 1  /mnt/NAS3/home/mary/HL-NF/scratch/ECTRES/resul...            1
# 2  /mnt/NAS3/home/mary/HL-NF/scratch/ECTRES/resul...            2
# 3  /mnt/NAS3/home/mary/HL-NF/scratch/ECTRES/resul...            1
# 4  /mnt/NAS3/home/mary/HL-NF/scratch/ECTRES/resul...            1
#
#                                  Intervals OncogenesAmplified
# 0                         5:580025-2945112              TERT,  \
# 1                      5:56760725-56995730                  ,
# 2  6:55197775-58257661,6:58341596-58700002             RAB23,
# 3                      6:63300000-64633728            PTP4A1,
# 4                        7:3427367-3487367                  ,
#
#    TotalIntervalSize  AmplifiedIntervalSize  AverageAmplifiedCopyCount
# 0            2365088                2365085                   4.544923  \
# 1             235006                 235005                   3.713199
# 2            3418294                3357386                   5.672345
# 3            1333729                1216199                   6.019590
# 4              60001                  60000                   3.777979
#
#    N_Chromosomes  N_SeqenceEdges  N_BreakpointEdges  N_CoverageShifts
# 0              1               3                  0                 2  \
# 1              1               1                  0                 0
# 2              1               9                  1                 5
# 3              1               2                  0                 1
# 4              1               1                  0                 0
#
#    N_MeanshiftSegmentsCopyCount>5  N_Foldbacks
# 0                               1            0  \
# 1                               0            0
# 2                               1            1
# 3                               0            0
# 4                               0            0
#
#    N_CoverageShiftsWithBreakpointEdges source_barcode sample_id
# 0                                    2          ECGI1      EG_8
# 1                                    0          ECGI1      EG_8
# 2                                    5          ECGI1      EG_8
# 3                                    1          ECGI1      EG_8
# 4                                    0          ECGI1      EG_8
